# %% [markdown]
# # Challenge: Promotions
#
# In this challenge, you'll develop codes to parse and analyze data returned from another API on Zalando such as [Promos homme (Men's Promotions)
# ](https://www.zalando.fr/promo-homme/) or [Promos femme (Women's Promotions)](https://www.zalando.fr/promo-femme/). The workflow is almost the same as in the guided lesson but you'll work with different data.

# %% [markdown]
# ## Obtaining the link
#
# Wrote your codes in the cell below to obtain the data from the API endpoint you choose. A recap of the workflow:
#
# 1. Examine the webpages and choose one that you want to work with.
#
# 1. Use Google Chrome's DevTools to inspect the XHR network requests. Find out the API endpoint that serves data to the webpage.
#
# 1. Test the API endpoint in the browser to verify its data.
#
# 1. Change the page number offset of the API URL to test if it's working.

# %%
# your code here

url = 'https://www.zalando.fr/api/catalog/articles?categories=promo-homme&limit=84&offset=84&sort=popularity'

# %% [markdown]
# ## Reading the data
#
# In the next cell, use Python to obtain data from the API endpoint you chose in the previous step. Workflow:
#
# 1. Import libraries.
#
# 1. Define the initial API endpoint URL.
#
# 1. Make request to obtain data of the 1st page. Flatten the data and store it in an empty object variable.
#
# 1. Find out the total page count in the 1st page data.
#
# 1. Use a FOR loop to make requests for the additional pages from 2 to page count. Append the data of each additional page to the flatterned data object.
#
# 1. Print and review the data you obtained.

# %%
# your code here
import json
import urllib
import requests
import pandas as pd
from pandas import json_normalize

# %%
response = urllib.request.urlopen(url)
results = json.load(response)

flattened_data = json_normalize(results)
flattened_data1 = json_normalize(flattened_data.articles[0])
flattened_data1
# Out:
#               sku                                               name  \
# 0   AD115O045-A11  STAN SMITH - Baskets basses - ftwwht/ftwwht/cr...
# 1   AD115O0DY-A12  STAN SMITH NEON HEEL SHOES - Baskets basses - ...
# 2   GS122E07J-C11  ROVIC ZIP 3D STRAIGHT TAPERED - Pantalon cargo...
# 3   TOB22G00X-K11  SCANTON BEMB - Jean slim - berry mid blue comfort
# 4   OS322E04A-K12      ONSMARK PANT - Pantalon classique - night sky
# ..            ...                                                ...
# 79  N1242E1C1-Q11  FLEX STRIDE - Short de sport - black/reflectiv...
# 80  PI922O0CI-A11                            T-shirt imprimé - white
# 81  PI922OA2T-K11                   T-shirt à manches longues - navy
# 82  NI122T01O-Q12                           Veste coupe-vent - black
# 83  PI982AA00-A12             2 PACK - T-shirt basique - white/black
#
#                                                 sizes  \
# 0   [36, 38, 40, 42, 44, 46, 48, 36 2/3, 37 1/3, 3...
# 1   [36, 38, 40, 42, 44, 46, 48, 36 2/3, 37 1/3, 3...
# 2   [27x30, 27x32, 27x34, 28x30, 28x32, 28x34, 29x...
# 3   [27x30, 27x32, 27x34, 27x36, 28x30, 28x32, 28x...
# 4   [28x30, 28x32, 28x34, 29x30, 29x32, 29x34, 30x...
# ..                                                ...
# 79                                 [S, M, L, XL, XXL]
# 80                             [XS, S, M, L, XL, XXL]
# 81                  [S, M, L, XL, XXL, 3XL, 4XL, 5XL]
# 82                             [XS, S, M, L, XL, XXL]
# 83         [XS, S, M, L, XL, XXL, 3XL, 4XL, 5XL, 6XL]
#
#                                               url_key  \
# 0   adidas-originals-stan-smith-baskets-basses-foo...
# 1   adidas-originals-stan-smith-baskets-basses-ad1...
# 2   g-star-rovic-zip-3d-tapered-pantalon-cargo-rav...
# 3   tommy-jeans-scanton-bemb-jean-slim-berry-mid-b...
# 4      only-and-sons-onsmark-pant-chino-os322e04a-k12
# ..                                                ...
# 79  nike-performance-flex-stride-short-de-sport-n1...
# 80       pier-one-t-shirt-imprime-white-pi922o0ci-a11
# 81  pier-one-t-shirt-a-manches-longues-navy-pi922o...
# 82   nike-sportswear-veste-legere-black-ni122t01o-q12
# 83      pier-one-2-pack-t-shirt-basique-pi982aa00-a12
#
#                                                 media        brand_name  \
# 0   [{'path': 'spp-media-p1/cce0afbed85e3ea2878af4...  adidas Originals
# 1   [{'path': 'spp-media-p1/e5a1f1bb4a773572a034c7...  adidas Originals
# 2   [{'path': 'spp-media-p1/c9b103017c7632e9bc0663...            G-Star
# 3   [{'path': 'spp-media-p1/8ce377485d3432fabcaafc...       Tommy Jeans
# 4   [{'path': 'spp-media-p1/804480cc8c2c344fa0c490...       Only & Sons
# ..                                                ...               ...
# 79  [{'path': 'spp-media-p1/132a89c99a893bbc857a95...  Nike Performance
# 80  [{'path': 'spp-media-p1/3c82c06caced3465bd7ab4...          Pier One
# 81  [{'path': 'spp-media-p1/6e0284944dfb326e81e574...          Pier One
# 82  [{'path': 'spp-media-p1/65a67368077c3c2a9fd8a4...   Nike Sportswear
# 83  [{'path': 'spp-media-p1/736fc361cc6c35188ee3f6...          Pier One
#
#     is_premium family_articles  \
# 0        False              []
# 1        False              []
# 2        False              []
# 3        False              []
# 4        False              []
# ..         ...             ...
# 79       False              []
# 80       False              []
# 81       False              []
# 82       False              []
# 83       False              []
#
#                                                 flags product_group  \
# 0   [{'key': 'discountRate', 'value': 'Jusqu’à -10...          shoe
# 1   [{'key': 'discountRate', 'value': '-25%', 'tra...          shoe
# 2   [{'key': 'discountRate', 'value': 'Jusqu’à -30...      clothing
# 3   [{'key': 'discountRate', 'value': '-20%', 'tra...      clothing
# 4   [{'key': 'discountRate', 'value': 'Jusqu’à -15...      clothing
# ..                                                ...           ...
# 79  [{'key': 'discountRate', 'value': 'Jusqu’à -20...      clothing
# 80  [{'key': 'discountRate', 'value': '-15%', 'tra...      clothing
# 81  [{'key': 'discountRate', 'value': '-10%', 'tra...      clothing
# 82  [{'key': 'discountRate', 'value': '-15%', 'tra...      clothing
# 83  [{'key': 'discountRate', 'value': '-20%', 'tra...      clothing
#
#    delivery_promises price.original price.promotional  \
# 0                 []        94,95 €           85,45 €
# 1                 []        99,95 €           74,95 €
# 2                 []        99,95 €           69,95 €
# 3                 []        99,95 €           79,95 €
# 4                 []        34,99 €           29,69 €
# ..               ...            ...               ...
# 79                []        44,95 €           35,95 €
# 80                []         9,99 €            8,49 €
# 81                []        14,99 €           13,49 €
# 82                []        79,95 €           67,95 €
# 83                []        14,99 €           11,99 €
#
#     price.has_different_prices  price.has_different_original_prices  \
# 0                         True                                False
# 1                        False                                False
# 2                         True                                False
# 3                        False                                False
# 4                         True                                False
# ..                         ...                                  ...
# 79                        True                                False
# 80                        True                                False
# 81                       False                                False
# 82                       False                                False
# 83                       False                                False
#
#     price.has_different_promotional_prices  \
# 0                                     True
# 1                                    False
# 2                                     True
# 3                                    False
# 4                                     True
# ..                                     ...
# 79                                    True
# 80                                    True
# 81                                   False
# 82                                   False
# 83                                   False
#
#     price.has_discount_on_selected_sizes_only outfits amount
# 0                                       False     NaN    NaN
# 1                                       False     NaN    NaN
# 2                                       False     NaN    NaN
# 3                                       False     NaN    NaN
# 4                                       False     NaN    NaN
# ..                                        ...     ...    ...
# 79                                      False     NaN    NaN
# 80                                      False     NaN    NaN
# 81                                      False     NaN    NaN
# 82                                      False     NaN    NaN
# 83                                      False     NaN    NaN
#
# [84 rows x 19 columns]

# %%
df=pd.DataFrame()
for i in range(10): #Le meto solo 10 para que no se pete la pagina. 
    k=10*i
    url=f'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset={k}&sort=sale'
    response = urllib.request.urlopen(url)
    results = json.load(response)
    flattened_data = json_normalize(results)
    flattened_data1 = json_normalize(flattened_data.articles[0])
    flattened_data1=flattened_data1.set_index('sku')
    df = df.append(flattened_data1)
    print(f"getting page {i} of {total_pages}", end='\r')
# Out:
# getting page 9 of 653

# %% [markdown]
# ## Bonus
#
# Extract the following information from the data:
#
# * The trending brand.
#
# * The product(s) with the highest discount.
#
# * The sum of discounts of all goods (sum_discounted_prices divided by sum_original_prices).

# %%
# your code here
df.brand_name.value_counts().index[0]
# Out:
# 'Nike Sportswear'

# %%
df['price.original']=df['price.original'].str.extract('(\d*,\d*)')
df['price.promotional']=df['price.promotional'].str.extract('(\d*,\d*)')

df['price.original'] = [x.replace(',', '.') for x in df['price.original']]
df['price.promotional'] = [x.replace(',', '.') for x in df['price.promotional']]
df['discount_amount']=df['price.original'].astype(float)-df['price.promotional'].astype(float)
df1=df.copy()
total_disc=df1.groupby(['name']).sum().discount_amount
total_disc.sort_values(ascending=False).index[0]
# Out:
# 'AIR MAX TAILWIND IV - Baskets basses - black'

# %%
total_disc=df1.groupby(['name']).sum().discount_amount
total_disc.sum()
# Out:
# 8449.5
